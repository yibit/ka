# %%
using GraphPlot
g = GraphPlot.graphfamous("karate")
gplot(g)
# Out:
# ┌ Info: Precompiling GraphPlot [a2cc645c-3eea-5389-862e-a155d0052231]
# └ @ Base loading.jl:1278
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.16261582796655488cx, -0.31923426044533176cy), (-0.07394740602588187cx, -0.26473024857179317cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.16068113217202007cx, -0.3227384861935249cy), (0.20641883403861616cx, -0.14188261352110892cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.17205869256393305cx, -0.3749242571750387cy), (-0.05161733879681082cx, -0.5227370750022405cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.2347468174259125cx, -0.3655717230615373cy), (-0.5388439354473965cx, -0.5695710381635354cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.23835003920644876cx, -0.3590339548221357cy), (-0.7038678320084224cx, -0.5649989465820027cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.23011814502593295cx, -0.37132918112245733cy), (-0.6476159417816415cx, -0.7708499652479832cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.16708106929430108cx, -0.3701532317076565cy), (0.046226661803193334cx, -0.5595504735511267cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.1722115040730383cx, -0.30832475540343013cy), (0.18583587569439144cx, 0.1352335051810623cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.24194985032028135cx, -0.3393009531797086cy), (-0.6083567758546883cx, -0.318882666130575cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.2266132329710997cx, -0.3087692159284877cy), (-0.5449675118556849cx, 0.07269179960438979cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.6654333260052205cx, -0.1489270560331856cy), (0.5526758860091324cx, 0.347544721690603cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.523143812425458cx, -0.06609926486056189cy), (0.47995577309913007cx, -0.19680528413138693cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.5372758587592016cx, 0.0174798652348558cy), (0.5424994932347246cx, 0.3464853564937521cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.8391065315192403cx, 0.5340493057822734cy), (0.642804195301492cx, 0.46489380136614755cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.8407803473962185cx, 0.5299781220666363cy), (0.5819449388644666cx, 0.40767193847389643cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.34313770302585084cx, 0.3056381451975074cy), (0.5649474588227567cx, 0.4297163253866618cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.3449533348282623c ...

# %%
x = 10
x = x + 1
# Out:
# 11

# %%
using Gadfly, RDatasets
iris = dataset("datasets", "iris")
# Out:
# 150×5 DataFrame
# │ Row │ SepalLength │ SepalWidth │ PetalLength │ PetalWidth │ Species   │
# │     │ Float64     │ Float64    │ Float64     │ Float64    │ Cat…      │
# ├─────┼─────────────┼────────────┼─────────────┼────────────┼───────────┤
# │ 1   │ 5.1         │ 3.5        │ 1.4         │ 0.2        │ setosa    │
# │ 2   │ 4.9         │ 3.0        │ 1.4         │ 0.2        │ setosa    │
# │ 3   │ 4.7         │ 3.2        │ 1.3         │ 0.2        │ setosa    │
# │ 4   │ 4.6         │ 3.1        │ 1.5         │ 0.2        │ setosa    │
# │ 5   │ 5.0         │ 3.6        │ 1.4         │ 0.2        │ setosa    │
# │ 6   │ 5.4         │ 3.9        │ 1.7         │ 0.4        │ setosa    │
# │ 7   │ 4.6         │ 3.4        │ 1.4         │ 0.3        │ setosa    │
# │ 8   │ 5.0         │ 3.4        │ 1.5         │ 0.2        │ setosa    │
# │ 9   │ 4.4         │ 2.9        │ 1.4         │ 0.2        │ setosa    │
# │ 10  │ 4.9         │ 3.1        │ 1.5         │ 0.1        │ setosa    │
# ⋮
# │ 140 │ 6.9         │ 3.1        │ 5.4         │ 2.1        │ virginica │
# │ 141 │ 6.7         │ 3.1        │ 5.6         │ 2.4        │ virginica │
# │ 142 │ 6.9         │ 3.1        │ 5.1         │ 2.3        │ virginica │
# │ 143 │ 5.8         │ 2.7        │ 5.1         │ 1.9        │ virginica │
# │ 144 │ 6.8         │ 3.2        │ 5.9         │ 2.3        │ virginica │
# │ 145 │ 6.7         │ 3.3        │ 5.7         │ 2.5        │ virginica │
# │ 146 │ 6.7         │ 3.0        │ 5.2         │ 2.3        │ virginica │
# │ 147 │ 6.3         │ 2.5        │ 5.0         │ 1.9        │ virginica │
# │ 148 │ 6.5         │ 3.0        │ 5.2         │ 2.0        │ virginica │
# │ 149 │ 6.2         │ 3.4        │ 5.4         │ 2.3        │ virginica │
# │ 150 │ 5.9         │ 3.0        │ 5.1         │ 1.8        │ virginica │

# %%
p = plot(iris, x=:SepalLength, y=:SepalWidth, Geom.point);

# %%
img = SVG("iris_plot.svg", 14cm, 8cm)
draw(img, p)
# Out:
# false

# %%
using Plots
# define the Lorenz attractor
Base.@kwdef mutable struct Lorenz
    dt::Float64 = 0.02
    σ::Float64 = 10
    ρ::Float64 = 28
    β::Float64 = 8/3
    x::Float64 = 1
    y::Float64 = 1
    z::Float64 = 1
end

function step!(l::Lorenz)
    dx = l.σ * (l.y - l.x);         l.x += l.dt * dx
    dy = l.x * (l.ρ - l.z) - l.y;   l.y += l.dt * dy
    dz = l.x * l.y - l.β * l.z;     l.z += l.dt * dz
end

attractor = Lorenz()


# initialize a 3D plot with 1 empty series
plt = plot3d(
    1,
    xlim = (-30, 30),
    ylim = (-30, 30),
    zlim = (0, 60),
    title = "Lorenz Attractor",
    marker = 2,
    fmt = :png
)

# build an animated gif by pushing new points to the plot, saving every 10th frame
@gif for i=1:1500
    step!(attractor)
    push!(plt, attractor.x, attractor.y, attractor.z)
end
# Out:
# ┌ Info: Saved animation to
# │   fn = /Users/mantra/taguba/mantra/ka/jupyter/tmp.gif
# └ @ Plots /Users/mantra/.julia/packages/Plots/qZHsp/src/animation.jl:98
# Plots.AnimatedGif("/Users/mantra/taguba/mantra/ka/jupyter/tmp.gif")
